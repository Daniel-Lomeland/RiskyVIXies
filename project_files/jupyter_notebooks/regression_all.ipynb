# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
from datetime import datetime
from matplotlib.pyplot import figure
import json
import pickle

# %%
# Read the News sentiment csv file into a pandas DataFrame
news_df = pd.read_csv('../resources/news/Descriptive_stats_1.0.csv')
news_df.head()
# Out:
#    Unnamed: 0   Published  Snippet_s  Lead_Paragraph_s  Main_Headline_s  \
# 0           0  10/14/2016   0.700000          0.700000         0.400000
# 1           1   5/15/2017   0.200000          0.200000        -0.200000
# 2           2   8/28/2017  -0.100000         -0.100000        -0.100000
# 3           3    1/1/2019   0.020000          0.020000         0.380000
# 4           4    1/2/2019  -0.054545         -0.054545         0.036364
#
#    count      mean       std       min       25%       50%       75%  max
# 0      3  0.600000  0.173205  0.400000  0.550000  0.700000  0.700000  0.7
# 1      3  0.066667  0.230940 -0.200000  0.000000  0.200000  0.200000  0.2
# 2      3 -0.100000  0.000000 -0.100000 -0.100000 -0.100000 -0.100000 -0.1
# 3      3  0.140000  0.230940  0.000000  0.010000  0.020000  0.210000  0.4
# 4      3 -0.024242  0.241437 -0.218182 -0.136364 -0.054545  0.072727  0.2

# %%
# Create a new dataframe with only the columns needed for the Regression
clean_news_df = news_df.drop(['Unnamed: 0','count'], axis=1)
clean_news_df = clean_news_df.set_index('Published')
clean_news_df.index.names = ['date']
clean_news_df.index = pd.to_datetime(clean_news_df.index)
clean_news_df.head()
# Out:
#             Snippet_s  Lead_Paragraph_s  Main_Headline_s      mean       std  \
# date
# 2016-10-14   0.700000          0.700000         0.400000  0.600000  0.173205
# 2017-05-15   0.200000          0.200000        -0.200000  0.066667  0.230940
# 2017-08-28  -0.100000         -0.100000        -0.100000 -0.100000  0.000000
# 2019-01-01   0.020000          0.020000         0.380000  0.140000  0.230940
# 2019-01-02  -0.054545         -0.054545         0.036364 -0.024242  0.241437
#
#                  min       25%       50%       75%  max
# date
# 2016-10-14  0.400000  0.550000  0.700000  0.700000  0.7
# 2017-05-15 -0.200000  0.000000  0.200000  0.200000  0.2
# 2017-08-28 -0.100000 -0.100000 -0.100000 -0.100000 -0.1
# 2019-01-01  0.000000  0.010000  0.020000  0.210000  0.4
# 2019-01-02 -0.218182 -0.136364 -0.054545  0.072727  0.2

# %%
# Read the News sentiment csv file into a pandas DataFrame
w2v_df = pd.read_csv('../resources/news/business_news_word2vec.csv')
w2v_df.head()
# Out:
#                  Unnamed: 0         0         1         2         3         4  \
# 0  2016-10-14T04:00:00+0000 -0.042708  0.029647 -0.019681  0.009444 -0.030000
# 1  2017-05-15T07:21:08+0000  0.028475  0.095679  0.023912  0.081352 -0.035714
# 2  2017-08-28T16:33:11+0000 -0.002913  0.007083 -0.019647  0.050519 -0.048486
# 3  2019-01-01T10:00:06+0000 -0.020165  0.114699 -0.038919  0.149319 -0.029073
# 4  2019-01-01T10:00:07+0000  0.062875  0.052707 -0.067801  0.108041 -0.057408
#
#           5         6         7         8    ...          290       291  \
# 0 -0.058390  0.025602 -0.037046  0.146306    ...    -0.107121 -0.026034
# 1 -0.142033 -0.019288 -0.052985  0.143840    ...    -0.146977  0.012309
# 2 -0.015724  0.035422 -0.023903  0.077841    ...     0.015891  0.018854
# 3 -0.021098 -0.019813 -0.087023  0.072137    ...    -0.100715  0.069874
# 4 -0.058799  0.003148 -0.099071  0.143119    ...    -0.027152  0.045913
#
#         292       293       294       295       296       297       298  \
# 0 -0.079626  0.095634  0.015284  0.013509  0.064372  0.004792  0.014158
# 1 -0.083553 -0.017334  0.005087  0.021395 -0.095197  0.040135  0.063836
# 2 -0.063055 -0.010825 -0.048286 -0.086072  0.034598 -0.077390  0.039180
# 3 -0.060326  0.026296  0.004639  0.040070  0.069238  0.006884  0.066581
# 4 -0.095576  0.008519  0.088440 -0.048104 -0.020682 -0.091771 -0.010306
#
#         299
# 0 -0.071216
# 1 -0.102547
# 2  0.016693
# 3 -0.048204
# 4  0.050415
#
# [5 rows x 301 columns]

# %%
# Clean the word to vec dataframe
clean_w2v_df = w2v_df.set_index('Unnamed: 0')
clean_w2v_df.index = pd.to_datetime(clean_w2v_df.index)
clean_w2v_df.index = clean_w2v_df.index.strftime('%Y-%m-%d')
clean_w2v_df.index.names = ['date']
clean_w2v_df.head()
# Out:
#                    0         1         2         3         4         5  \
# date
# 2016-10-14 -0.042708  0.029647 -0.019681  0.009444 -0.030000 -0.058390
# 2017-05-15  0.028475  0.095679  0.023912  0.081352 -0.035714 -0.142033
# 2017-08-28 -0.002913  0.007083 -0.019647  0.050519 -0.048486 -0.015724
# 2019-01-01 -0.020165  0.114699 -0.038919  0.149319 -0.029073 -0.021098
# 2019-01-01  0.062875  0.052707 -0.067801  0.108041 -0.057408 -0.058799
#
#                    6         7         8         9    ...          290  \
# date                                                  ...
# 2016-10-14  0.025602 -0.037046  0.146306  0.091940    ...    -0.107121
# 2017-05-15 -0.019288 -0.052985  0.143840  0.017806    ...    -0.146977
# 2017-08-28  0.035422 -0.023903  0.077841  0.049966    ...     0.015891
# 2019-01-01 -0.019813 -0.087023  0.072137  0.042570    ...    -0.100715
# 2019-01-01  0.003148 -0.099071  0.143119  0.078700    ...    -0.027152
#
#                  291       292       293       294       295       296  \
# date
# 2016-10-14 -0.026034 -0.079626  0.095634  0.015284  0.013509  0.064372
# 2017-05-15  0.012309 -0.083553 -0.017334  0.005087  0.021395 -0.095197
# 2017-08-28  0.018854 -0.063055 -0.010825 -0.048286 -0.086072  0.034598
# 2019-01-01  0.069874 -0.060326  0.026296  0.004639  0.040070  0.069238
# 2019-01-01  0.045913 -0.095576  0.008519  0.088440 -0.048104 -0.020682
#
#                  297       298       299
# date
# 2016-10-14  0.004792  0.014158 -0.071216
# 2017-05-15  0.040135  0.063836 -0.102547
# 2017-08-28 -0.077390  0.039180  0.016693
# 2019-01-01  0.006884  0.066581 -0.048204
# 2019-01-01 -0.091771 -0.010306  0.050415
#
# [5 rows x 300 columns]

# %%
# Read the VIX history csv file into a pandas DataFrame
vix_df = pd.read_csv('../resources/vix/vix_history.csv')
vix_df.head()
# Out:
#        Date  VIX Open  VIX High  VIX Low  VIX Close
# 0  1/2/2004     17.96     18.68    17.54      18.22
# 1  1/5/2004     18.45     18.49    17.44      17.49
# 2  1/6/2004     17.66     17.67    16.19      16.73
# 3  1/7/2004     16.72     16.75    15.50      15.50
# 4  1/8/2004     15.42     15.68    15.32      15.61

# %%
# Create a new dataframe with only the columns needed for the Regression
clean_vix_df = vix_df.drop(['VIX Open','VIX High','VIX Low'], axis=1).set_index('Date')
clean_vix_df.index.names = ['date']
clean_vix_df.rename(columns={'VIX Close': 'vix_close'}, inplace=True)
clean_vix_df.index = pd.to_datetime(clean_vix_df.index, format="%m/%d/%Y")
clean_vix_df.head()
# Out:
#             vix_close
# date
# 2004-01-02      18.22
# 2004-01-05      17.49
# 2004-01-06      16.73
# 2004-01-07      15.50
# 2004-01-08      15.61

# %%
clean_vix_df = clean_vix_df.pct_change()*100
clean_vix_df.head()
# Out:
#             vix_close
# date
# 2004-01-02        NaN
# 2004-01-05  -4.006586
# 2004-01-06  -4.345340
# 2004-01-07  -7.352062
# 2004-01-08   0.709677

# %%
# Merge the word to vec and VIX data
merged_w2v_df=pd.merge(clean_w2v_df, clean_news_df, how='inner', left_index=True, right_index=True)
merged_w2v_df.head()
# Out:
#                    0         1         2         3         4         5  \
# date
# 2016-10-14 -0.042708  0.029647 -0.019681  0.009444 -0.030000 -0.058390
# 2017-05-15  0.028475  0.095679  0.023912  0.081352 -0.035714 -0.142033
# 2017-08-28 -0.002913  0.007083 -0.019647  0.050519 -0.048486 -0.015724
# 2019-01-01 -0.020165  0.114699 -0.038919  0.149319 -0.029073 -0.021098
# 2019-01-01  0.062875  0.052707 -0.067801  0.108041 -0.057408 -0.058799
#
#                    6         7         8         9 ...   Snippet_s  \
# date                                               ...
# 2016-10-14  0.025602 -0.037046  0.146306  0.091940 ...        0.70
# 2017-05-15 -0.019288 -0.052985  0.143840  0.017806 ...        0.20
# 2017-08-28  0.035422 -0.023903  0.077841  0.049966 ...       -0.10
# 2019-01-01 -0.019813 -0.087023  0.072137  0.042570 ...        0.02
# 2019-01-01  0.003148 -0.099071  0.143119  0.078700 ...        0.02
#
#             Lead_Paragraph_s  Main_Headline_s      mean       std  min   25%  \
# date
# 2016-10-14              0.70             0.40  0.600000  0.173205  0.4  0.55
# 2017-05-15              0.20            -0.20  0.066667  0.230940 -0.2  0.00
# 2017-08-28             -0.10            -0.10 -0.100000  0.000000 -0.1 -0.10
# 2019-01-01              0.02             0.38  0.140000  0.230940  0.0  0.01
# 2019-01-01              0.02             0.38  0.140000  0.230940  0.0  0.01
#
#              50%   75%  max
# date
# 2016-10-14  0.70  0.70  0.7
# 2017-05-15  0.20  0.20  0.2
# 2017-08-28 -0.10 -0.10 -0.1
# 2019-01-01  0.02  0.21  0.4
# 2019-01-01  0.02  0.21  0.4
#
# [5 rows x 310 columns]

# %%
merged_all_df=pd.merge(merged_w2v_df,clean_vix_df, how='inner', left_index=True, right_index=True)
merged_all_df.head()
# Out:
#                    0         1         2         3         4         5  \
# date
# 2016-10-14 -0.042708  0.029647 -0.019681  0.009444 -0.030000 -0.058390
# 2017-05-15  0.028475  0.095679  0.023912  0.081352 -0.035714 -0.142033
# 2017-08-28 -0.002913  0.007083 -0.019647  0.050519 -0.048486 -0.015724
# 2019-01-02  0.144113  0.129674 -0.027830  0.098580 -0.037144 -0.040632
# 2019-01-02  0.123807 -0.056305 -0.058940 -0.003916 -0.006215  0.061412
#
#                    6         7         8         9    ...      \
# date                                                  ...
# 2016-10-14  0.025602 -0.037046  0.146306  0.091940    ...
# 2017-05-15 -0.019288 -0.052985  0.143840  0.017806    ...
# 2017-08-28  0.035422 -0.023903  0.077841  0.049966    ...
# 2019-01-02  0.109305 -0.168248  0.135254  0.042855    ...
# 2019-01-02  0.016164 -0.072978  0.083811 -0.072276    ...
#
#             Lead_Paragraph_s  Main_Headline_s      mean       std       min  \
# date
# 2016-10-14          0.700000         0.400000  0.600000  0.173205  0.400000
# 2017-05-15          0.200000        -0.200000  0.066667  0.230940 -0.200000
# 2017-08-28         -0.100000        -0.100000 -0.100000  0.000000 -0.100000
# 2019-01-02         -0.054545         0.036364 -0.024242  0.241437 -0.218182
# 2019-01-02         -0.054545         0.036364 -0.024242  0.241437 -0.218182
#
#                  25%       50%       75%  max  vix_close
# date
# 2016-10-14  0.550000  0.700000  0.700000  0.7  -3.415219
# 2017-05-15  0.000000  0.200000  0.200000  0.2   0.192308
# 2017-08-28 -0.100000 -0.100000 -0.100000 -0.1   0.354610
# 2019-01-02 -0.136364 -0.054545  0.072727  0.2  -8.654603
# 2019-01-02 -0.136364 -0.054545  0.072727  0.2  -8.654603
#
# [5 rows x 311 columns]

# %%
# Drop rows with NaNs
merged_all_df.dropna(inplace=True)
merged_all_df.head()
# Out:
#                    0         1         2         3         4         5  \
# date
# 2016-10-14 -0.042708  0.029647 -0.019681  0.009444 -0.030000 -0.058390
# 2017-05-15  0.028475  0.095679  0.023912  0.081352 -0.035714 -0.142033
# 2017-08-28 -0.002913  0.007083 -0.019647  0.050519 -0.048486 -0.015724
# 2019-01-02  0.144113  0.129674 -0.027830  0.098580 -0.037144 -0.040632
# 2019-01-02  0.123807 -0.056305 -0.058940 -0.003916 -0.006215  0.061412
#
#                    6         7         8         9    ...      \
# date                                                  ...
# 2016-10-14  0.025602 -0.037046  0.146306  0.091940    ...
# 2017-05-15 -0.019288 -0.052985  0.143840  0.017806    ...
# 2017-08-28  0.035422 -0.023903  0.077841  0.049966    ...
# 2019-01-02  0.109305 -0.168248  0.135254  0.042855    ...
# 2019-01-02  0.016164 -0.072978  0.083811 -0.072276    ...
#
#             Lead_Paragraph_s  Main_Headline_s      mean       std       min  \
# date
# 2016-10-14          0.700000         0.400000  0.600000  0.173205  0.400000
# 2017-05-15          0.200000        -0.200000  0.066667  0.230940 -0.200000
# 2017-08-28         -0.100000        -0.100000 -0.100000  0.000000 -0.100000
# 2019-01-02         -0.054545         0.036364 -0.024242  0.241437 -0.218182
# 2019-01-02         -0.054545         0.036364 -0.024242  0.241437 -0.218182
#
#                  25%       50%       75%  max  vix_close
# date
# 2016-10-14  0.550000  0.700000  0.700000  0.7  -3.415219
# 2017-05-15  0.000000  0.200000  0.200000  0.2   0.192308
# 2017-08-28 -0.100000 -0.100000 -0.100000 -0.1   0.354610
# 2019-01-02 -0.136364 -0.054545  0.072727  0.2  -8.654603
# 2019-01-02 -0.136364 -0.054545  0.072727  0.2  -8.654603
#
# [5 rows x 311 columns]

# %%
# Export the data
# merged_all_df.to_csv("../resources/vix/all.csv")

# %%
# Assign the data to X and y
x_columns = merged_all_df.columns.tolist()
del x_columns[-1]

X = merged_all_df[x_columns]
y = merged_all_df["vix_close"].values.reshape(-1, 1)
print(X.shape, y.shape)

print("Shape: ", X.shape, y.shape)
# Out:
# (989, 310) (989, 1)
# Shape:  (989, 310) (989, 1)

# %%
# Use train_test_split to create training and testing data
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=12)

# %%
# Create the model using LinearRegression
from sklearn.linear_model import LinearRegression
model = LinearRegression()

# %%
# Fit the model to the training data and calculate the scores for the training and testing data
model.fit(X_train, y_train)
training_score = model.score(X_train, y_train)
testing_score = model.score(X_test, y_test)
print(training_score)
print(testing_score)
# Out:
# 0.4253678523710773
# -0.8228254398610375

# %%
# Plot the Residuals for the Training and Testing data
plt.style.use('ggplot')
figure(num=None, figsize=(11, 7))
plt.scatter(model.predict(X_train), model.predict(X_train) - y_train, c="#FF7700", label="Training Data", marker='o',s=75)
plt.scatter(model.predict(X_test), model.predict(X_test) - y_test, c="#4B8937", label="Testing Data", marker='o',s=75)
plt.legend()
plt.hlines(y=0, xmin=y.min(), xmax=y.max(), colors="black",linestyles="dotted")
plt.title("Residual Plot")
# Out:
# Text(0.5, 1.0, 'Residual Plot')

# %%
print('Weight coefficients: ', model.coef_)
print('y-axis intercept: ', model.intercept_)
# Out:
# Weight coefficients:  [[-8.50762628e+00  3.67500291e+00  1.39330864e+01  5.24107774e+00
#   -3.67569058e+00 -4.12238297e+00  2.03354001e+01  9.25342751e+00
#   -1.14413643e+01 -2.47932005e+00 -1.92156884e+00 -9.35165230e+00
#    1.96603829e+01  8.95017382e+00 -2.31298710e+01  1.26005643e+01
#   -1.20408665e+00  1.38615649e+01  2.01822926e+00  7.73029005e+00
#    2.83776089e+00  6.05618413e-01  9.08860125e-01  3.62218286e-01
#   -5.43769239e+00 -7.95681590e+00  6.17664946e+00  2.81737934e+00
#    1.24796160e+01  5.22258067e+00  2.84378364e+00 -7.61447115e+00
#   -3.90868488e+00  2.69519893e+00  1.06160661e+01  9.21806160e+00
#   -7.25811508e+00  5.03125938e+00 -1.05183677e+01  1.16512234e+01
#   -1.44126406e+01  1.06217568e+01  1.26886407e+01  8.78370235e-01
#   -5.57361468e+00  9.61893747e+00 -6.24064861e+00 -1.41628332e+01
#    4.74774612e+00  1.37304576e+01 -3.61440327e+00  1.13216083e+01
#   -6.68853979e+00 -2.37733397e+00 -6.82137070e+00 -9.83990108e+00
#   -1.31575825e+01 -9.02081830e+00 -6.19555979e+00 -8.72564285e+00
#   -1.75149341e+01  4.54890881e+00 -5.30705080e+00  1.87810981e+00
#   -1.15244369e+01 -7.33937133e+00  2.94322636e+00 -1.97980978e-01
#   -3.64723099e+00  4.46099445e+00 -7.92210685e-01  5.12279781e+00
#    1.30551744e+01 -1.23219440e+01 -2.20779761e+01 -8.59705425e+00
#    1.40667702e+01 -1.30550675e+01 -8.14962350e+00  8.35620204e+00
#    7.10534363e+00 -1.89720618e-02 -6.13501857e-01 -7.12726011e+00
#   -6.15065702e+00 -2.77213482e+00 -6.88715129e+00 -1.01374770e+01
#    7.44320803e+00 -8.27023567e+00  1.84257535e+00  7.88141752e+00
#    1.36237254e+01 -4.19895244e-01 -6.31791116e+00  1.03008738e+01
#    3.26544445e+00 -1.81365959e+01 -4.55619283e+00  4.95983668e+00
#   -4.59683334e+00 -1.58606550e+01 -4.09570981e+00 -2.61812012e+01
#    5.16986862e+00  5.80280677e+00 -6.39650769e-01  3.79455751e+00
#   -1.97993046e+01 -2.65956298e+01  1.41498965e+01 -1.78301317e+01
#   -1.08064156e+01 -4.98808768e+00  1.23990207e+01  2.64305743e+00
#    5.49350680e-01 -1.39578227e+00  2.73068092e+01 -8.91110214e+00
#   -2.83199952e+00  5.47537491e-01 -2.82770848e+00 -3.48603195e+00
#   -1.30533547e+01  1.42542247e+01 -1.61472028e+00  3.50777440e+00
#    7.74774081e+00  5.59136525e+00  2.37764700e+00  4.58152722e+00
#    2.64819898e-02 -3.78499173e+00  7.35921754e+00 -8.92918577e+00
#   -1.46809770e+01  7.03530242e-01 -5.24923869e-01  6.80037594e-02
#    1.11198081e+01  3.21781149e+00  3.94050707e+00  4.04488309e+00
#   -1.55070702e+00  1.34232362e+01  1.07561928e+01  1.40548941e+01
#    4.31640854e+00 -5.72115511e+00 -6.88975401e+00 -3.58931149e+00
#    1.05121646e+00 -2.34468938e+00 -2.33280456e+01  2.06379408e-01
#   -6.22752785e+00 -1.67345313e+01  1.06396278e+00  9.60849924e+00
#    6.56303712e+00 -9.87142136e+00  4.57605100e+00  1.00427654e+01
#   -9.07792599e+00  4.37489459e+00  1.16592711e+01  9.57717744e+00
#   -8.31496213e+00  3.77637390e+00 -9.29068457e+00 -6.15297349e+00
#   -5.69748509e-01  4.14729695e+00 -7.26331471e+00 -2.91849482e+00
#    5.36875055e+00 -2.45655578e+00  4.85739908e+00 -1.17658949e+00
#   -1.38897864e+01 -7.40802503e+00  7.47043675e-01  6.72304566e+00
#    5.49275562e+00 -2.11499068e+00 -5.96227251e+00 -1.39726606e+01
#   -2.03714178e-01 -8.69362473e+00  6.87245353e+00 -2.15514495e+01
#    7.52887849e+00  2.05627988e+00  7.07506752e+00 -1.41729806e+01
#    6.14733208e+00  2.07796495e+00 -7.24478472e+00 -2.55855129e+01
#    1.03775697e+01  1.14698674e+01 -1.77794468e+01  1.42836076e-01
#   -2.91294451e+01  5.63857996e+00  9.94721279e-01 -5.03872355e-02
#    1.08799300e+00 -8.25601550e+00 -1.04157395e+01 -6.59075385e+00
#    1.65166708e+00  1.22523095e+01 -7.36019321e+00  1.02016926e+01
#   -5.87863223e+00  1.05997218e+01 -1.92191441e+01  1.21801778e+01
#    1.61739522e+01  6.65501247e+00  1.06848040e+01  3.00118510e+00
#    3.89743974e+00  9.88376210e+00 -6.94400283e+00 -4.18428999e+00
#    7.19523045e+00  5.54725852e+00 -7.46093014e+00  1.20500882e+01
#   -7.55390506e+00 -1.28003344e+01 -2.27326032e+00  4.53238963e+00
#    3.62217694e+00 -8.24954011e+00  7.79352653e+00  6.13095064e+00
#   -1.11039761e+01 -6.73762844e+00  1.09526808e+01 -6.48917104e+00
#    1.23851082e+01 -2.89088613e+00  4.47673018e+00  8.19107889e+00
#    1.28861920e+01  5.77319868e+00  1.38903941e+01  2.58564375e+01
#   -3.52767775e+00  7.88534394e+00  1.47531496e+00  5.90451981e+00
#    1.84728007e+01  5.74280320e+00 -1.62032501e+01 -2.05034042e+01
#    8.58395597e+00  1.70750018e+01  1.30136315e+01  1.72075107e+00
#    5.24180420e+00  1.72520521e+00 -5.31378050e+00  1.88949856e+00
#    1.40497074e+01  1.35406867e+01  1.03122464e+01 -8.26750178e+00
#   -8.58151434e+00  3.64760663e+00 -7.44728665e+00 -8.66452690e+00
#    7.43254546e+00  1.09770096e+01 -5.97461413e+00 -9.07836185e+00
#   -2.97465476e+01 -1.45990368e+01 -4.49430647e+00  1.77725868e+00
#   -1.65083496e+01  2.15115110e+00  2.67286954e+00  8.01674791e+00
#    1.35445851e+01  1.79579731e+01  6.28713094e+00  5.84004986e+00
#   -2.40343648e+00  4.82846958e+00 -2.11279680e+01 -1.63627140e+01
#    5.77649028e-01  4.79003330e+00  1.35712832e+01 -2.93272261e+00
#   -6.57482419e+13 -1.90335375e+14 -1.02550173e+09  1.51850171e+09
#   -1.00661091e+09  9.98115262e+08 -2.11989571e+09  2.56083774e+14
#   -1.25657785e+09  1.72879050e+09]]
# y-axis intercept:  [-23.42463179]

# %%
# Evaluate results
predictions = model.predict(X)
print(f"True output: {y[0]}")
print(f"Predicted output: {predictions[0]}")
print(f"Prediction Error: {predictions[0]-y[0]}")
# Out:
# True output: [-3.41521869]
# Predicted output: [-1.02022834]
# Prediction Error: [2.39499035]

# %%
from sklearn.metrics import mean_squared_error, r2_score
mean_squared_error(y_test, model.predict(X_test))
# Out:
# 73.97755035878207

# %%
r2_score(y_test, model.predict(X_test))
# Out:
# -0.8228254398610375

# %%
# Get min and max values
x_min = X.min()
x_max = X.max()
y_min_actual = y.min()
y_max_actual = y.max()
y_min = 101.896225057 + 12.44002424 * x_min
y_max = 101.896225057 + 12.44002424 * x_max
print(f"Actual Min Value: {y_min_actual}")
print(f"Calculated Min Value: {y_min}")
print(f"Actual Max Value: {y_max_actual}")
# Out:
# Actual Min Value: -15.992141453831044
# Calculated Min Value: 0                   100.035081
# 1                   100.679228
# 2                    99.824001
# 3                   100.671266
# 4                    99.808208
# 5                    99.551355
# 6                   100.091799
# 7                    99.075555
# 8                   101.183262
# 9                   100.683419
# 10                   99.275909
# 11                   98.636388
# 12                   98.988187
# 13                  100.078349
# 14                   98.594721
# 15                  100.915237
# 16                  100.249989
# 17                  101.162087
# 18                  100.439462
# 19                   99.098174
# 20                  100.188071
# 21                  100.100193
# 22                  100.166664
# 23                   99.502978
# 24                   99.904637
# 25                   99.598667
# 26                   99.314856
# 27                  100.102640
# 28                  100.219054
# 29                   99.222285
#                        ...
# 280                  99.253175
# 281                  99.757969
# 282                  99.906856
# 283                 100.398725
# 284                 100.234706
# 285                  99.530122
# 286                  98.687007
# 287                 100.538635
# 288                 100.546797
# 289                 100.097493
# 290                  98.865344
# 291                  98.919418
# 292                  98.798367
# 293                  99.866052
# 294                  99.782678
# 295                  99.404055
# 296                  99.996636
# 297                  98.517434
# 298                 100.589127
# 299                  99.621426
# Snippet_s            95.498498
# Lead_Paragraph_s     95.498498
# Main_Headline_s      97.127549
# mean                 97.275645
# std                 101.896225
# min                  94.965354
# 25%                  95.231926
# 50%                  95.498498
# 75%                  98.430790
# max                 100.652223
# Length: 310, dtype: float64
# Actual Max Value: 20.909757887013946

# %%
# Try to make on a new prediction
sample_data = merged_all_df.iloc[3].tolist()
del sample_data[-1]
new_value = np.array([sample_data])
y_pred = model.predict(new_value)
print(y_pred)
# Out:
# [[1.48344301]]

# %%
print(type(y_pred))
# Out:
# <class 'numpy.ndarray'>

# %%
# Save the mode
filename = '../resources/ml_model/lr_model_all.pkl'
pickle.dump(model, open(filename, 'wb'))

# %%
# Load model and make a prediction
model = pickle.load(open('../resources/ml_model/lr_model_all.pkl','rb'))
prediction = model.predict([sample_data])
print(prediction)
# Out:
# [[1.48344301]]

# %%
prediction_list = np.array(prediction).tolist()
prediction_value = round(prediction_list[0][0],2)
print(prediction_value)
# Out:
# 1.48
